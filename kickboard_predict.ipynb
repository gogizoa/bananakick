# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/HYAI/yolov5
# Out:
# /content/drive/MyDrive/HYAI/yolov5

# %%
# %pip install -qr requirements.txt                 # 필수 라이브러리 설치

# %%
# !python train.py --img 640 --batch 16 --epochs 50 --data /content/drive/MyDrive/HYAI/yolov5/data/kickboard_dataset.yaml --cfg ./models/yolov5s.yaml --weights yolov5s.pt --name yolov5s_results
# Out:
# WARNING ⚠️ user config directory is not writeable, defaulting to '/tmp/Ultralytics'.
# train: weights=yolov5s.pt, cfg=./models/yolov5s.yaml, data=/content/drive/MyDrive/HYAI/yolov5/data/kickboard_dataset.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=50, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=yolov5s_results, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v7.0-178-ga199480 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# ...

# %%
# !python val.py --data "/content/drive/MyDrive/HYAI/yolov5/data/kickboard_dataset.yaml" --img 640 --weights "/content/drive/MyDrive/HYAI/yolov5/runs/train/yolov5s_results/weights/best.pt"
# Out:
# val: data=/content/drive/MyDrive/HYAI/yolov5/data/kickboard_dataset.yaml, weights=['/content/drive/MyDrive/HYAI/yolov5/runs/train/yolov5s_results/weights/best.pt'], batch_size=32, imgsz=640, conf_thres=0.001, iou_thres=0.6, max_det=300, task=val, device=, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=exp, exist_ok=False, half=False, dnn=False
# YOLOv5 🚀 v7.0-178-ga199480 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# YOLOv5s summary: 157 layers, 7018216 parameters, 0 gradients, 15.8 GFLOPs
# val: Scanning /content/drive/MyDrive/HYAI/yolov5/data/kickboard_dataset/valid/labels.cache... 288 images, 0 backgrounds, 0 corrupt: 100% 288/288 [00:00<?, ?it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 9/9 [00:09<00:00,  1.06s/it]
# ...

# %%
# !python detect.py --img 640 --weights "/content/drive/MyDrive/HYAI/yolov5/runs/train/yolov5s_results/weights/best.pt" --source "/content/drive/MyDrive/HYAI/yolov5/data/kickboard_dataset/test/images"
# Out:
# detect: weights=['/content/drive/MyDrive/HYAI/yolov5/runs/train/yolov5s_results/weights/best.pt'], source=/content/drive/MyDrive/HYAI/yolov5/data/kickboard_dataset/test/images, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-178-ga199480 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# YOLOv5s summary: 157 layers, 7018216 parameters, 0 gradients, 15.8 GFLOPs
# image 1/25 /content/drive/MyDrive/HYAI/yolov5/data/kickboard_dataset/test/images/100.jpeg: 384x640 1 nonhelmet, 1 multiple, 43.4ms
# ...
